# %%
import pandas as pd
import japanize_matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.read_parquet("C:/Users/takah/investigate/Navya-202311-date.parquet")

# %%
x = "timestamp"
y = "speed_value"

df.plot(x=x, y=y, figsize=(9, 6))
plt.title("2023年11月2日-19日")
plt.xlabel(x, fontsize=15)
plt.ylabel(y + " (m/sec)", fontsize=15)
plt.xlim("2023-11-02 05:42:13", "2023-11-19 14:33:00")
plt.ylim()
plt.grid(color="dimgray", linestyle="--", linewidth="0.5")
